# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df  = pd.read_csv("/content/drive/My Drive/DataAnalysisWithPython/Libraries/DataCleaningProcess/DataCleaningProcess01/olympics.csv")
dataframe  = pd.read_csv("/content/drive/My Drive/DataAnalysisWithPython/Libraries/DataCleaningProcess/DataCleaningProcess01/noc_regions.csv")

# %% [markdown]
# #Data Analysis And Manipulation:

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
dataframe.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
dataframe.tail()
# Out:
#      NOC    region        notes
# 225  YEM     Yemen          NaN
# 226  YMD     Yemen  South Yemen
# 227  YUG    Serbia   Yugoslavia
# 228  ZAM    Zambia          NaN
# 229  ZIM  Zimbabwe          NaN

# %% [markdown]
# **Merging the both csv files:**

# %%
athletes_df = df.merge(dataframe, how = 'left', on = 'NOC')
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
athletes_df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'region', 'notes'],
#       dtype='object')

# %% [markdown]
# **Rename The Columns Name:**

# %%
athletes_df.rename(columns={'region':'Region', 'notes':'Notes'}, inplace = True)
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       Region Notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %% [markdown]
# **Removing the unused or irrelevant columns:**

# %%
# # Dropping unused columns.
# to_drop = ['Education']
# df.drop(to_drop, inplace = True, axis = 1)
# df.head(5)

# %%
athletes_df.shape
# Out:
# (271116, 17)

# %%
athletes_df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'Region', 'Notes'],
#       dtype='object')

# %%
athletes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
athletes_df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# **Check for missing or null values in the DataFrame:**

# %%
athletes_df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %%
# Indian Athlete details
athletes_df.query('Team=="India"').head(5)
# Out:
#       ID                             Name Sex   Age  Height  Weight   Team  \
# 505  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 506  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 895  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 896  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 897  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
#
#      NOC        Games  Year  Season         City      Sport  \
# 505  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 506  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 895  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 896  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 897  IND  1988 Summer  1988  Summer        Seoul  Athletics
#
#                                       Event Medal Region Notes
# 505      Athletics Men's 110 metres Hurdles   NaN  India   NaN
# ...

# %%
# Top countries participation

top_10_countries= athletes_df.Team.value_counts().sort_values(ascending=False).head(10)
top_10_countries
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
# Top 10 countries plotting
plt.figure(figsize=(10,5))
#plt.xticks(rotation=20)
plt.title('Overall participation by countries')
sns.barplot(x=top_10_countries.index, y=top_10_countries, palette = 'Set2')
# Out:
# <Axes: title={'center': 'Overall participation by countries'}, ylabel='Team'>

# %%
plt.figure(figsize=(15,6))
plt.title("Age distribution of the athletes")
plt.xlabel('Age')
plt.ylabel('Number of participants')
plt.hist(athletes_df.Age, bins = np.arange(10,80,2), color='magenta', edgecolor='white');

# %%
# Winter Olympics Sports

winter_sports = athletes_df[athletes_df.Season == 'Winter'].Sport.unique()
winter_sports
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %%
# Summer Olympics Sports

summer_sports = athletes_df[athletes_df.Season == 'Summer'].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
# Male & Female participants

gender_counts = athletes_df.Sex.value_counts()
gender_counts
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(14,8))
plt.title('Gender Distribution in Oylmpics')
plt.pie(gender_counts, labels=gender_counts.index,  autopct='%1.2f%%', startangle = 190);

# %%
# Total Medals
total_medals_df= athletes_df.Medal.value_counts()
total_medals_df
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
# Total number of female athletes in each olympics

female_participants= athletes_df[(athletes_df.Sex=='F') & (athletes_df.Season=='Summer')][['Sex', 'Year']]
female_participants= female_participants.groupby('Year').count().reset_index()
female_participants.tail()
# Out:
#     Year   Sex
# 23  2000  5431
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223

# %% [markdown]
# **There is a increase in the women's participation over the years:**

# %%
womenOlympics = athletes_df[(athletes_df.Sex=='F') & (athletes_df.Season=='Summer')]

# %%
# Plotting of Women's Participation

sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
sns.countplot(x='Year', data = womenOlympics, palette="Spectral")
plt.title('Women Participation in the Olympics')
# Out:
# Text(0.5, 1.0, 'Women Participation in the Olympics')

# %% [markdown]
# **By the line graph so you can have the better understanding about how female athletes participation have increased over the years**

# %%
part = womenOlympics.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(20, 10))
part.loc[:,'F'].plot()
plt.title('Plot of Female Athletes over the years')
# Out:
# Text(0.5, 1.0, 'Plot of Female Athletes over the years')

# %%
# Gold medal winnig athletes

goldMedals = athletes_df[(athletes_df.Medal=='Gold')]
goldMedals.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal   Region Notes
# 3        Tug-Of-War Men's Tug-Of-War  Gold  Denmark   NaN
# ...

# %%
goldMedals = goldMedals[np.isfinite(goldMedals['Age'])]

# %%
# Gold won beyond the age 55

goldMedals['ID'][goldMedals['Age']>55].count()
# Out:
# 27

# %%
sporting_event = goldMedals['Sport'][goldMedals['Age']>55]
sporting_event.head()
# Out:
# 7961               Sailing
# 13396        Equestrianism
# 30323             Alpinism
# 63622              Sailing
# 104003    Art Competitions
# Name: Sport, dtype: object

# %%
# Plot for sporting event beyond age of 55

sns.set(style="darkgrid")
plt.figure(figsize=(12,6))
plt.tight_layout()
sns.countplot(sporting_event, palette="Set1")
plt.title('Gold Medals for Athletes over 55 years')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Number of Gold Medals from each country

goldMedals.Region.value_counts().reset_index(name='Medal')
# Out:
#           index  Medal
# 0           USA   2627
# 1        Russia   1599
# 2       Germany   1293
# 3            UK    657
# 4         Italy    567
# ..          ...    ...
# 92      Grenada      1
# 93       Jordan      1
# 94      Vietnam      1
# 95  Ivory Coast      1
# 96   Tajikistan      1
#
# [97 rows x 2 columns]

# %%
# Plotting Gold medals per country

totalGoldmedals = goldMedals.Region.value_counts().reset_index(name='Medal').head(6)
g = sns.catplot(x="index", y="Medal", data = totalGoldmedals, height=5, kind="bar", palette="magma")
g.despine(left=True)
g.set_xlabels("Top 6 countries")
g.set_ylabels("Number of Medals")
plt.title('Gold Medals per Country')
# Out:
# Text(0.5, 1.0, 'Gold Medals per Country')

# %%
# Rio Oylmpics
max_year = athletes_df.Year.max()
print("Rio Olympics - 2016")
team_names = athletes_df[(athletes_df.Year== max_year) & (athletes_df.Medal=='Gold')].Team

team_names.value_counts().head(10)
# Out:
# Rio Olympics - 2016
# United States    137
# Great Britain     64
# Russia            50
# Germany           47
# China             44
# Brazil            34
# Australia         23
# Argentina         21
# France            20
# Japan             17
# Name: Team, dtype: int64

# %%
sns.barplot(x = team_names.value_counts().head(20), y= team_names.value_counts().head(20).index)

plt.ylabel(None);
plt.xlabel('Countrywise Medals for Rio Olympics 2016');

# %%
# Excluding the null values

not_null_medal = athletes_df[(athletes_df['Height']. notnull()) & (athletes_df['Weight']. notnull())]

# %%
# Plotting scatterplot "Height vs Weight of the Olympic Medalists"

plt.figure(figsize=(12, 10))
axis = sns.scatterplot(x="Height", y="Weight", data = not_null_medal, hue="Sex")
plt.title('Height vs Weight of the Olympic Medalists')
# Out:
# Text(0.5, 1.0, 'Height vs Weight of the Olympic Medalists')

# %%
newdf=athletes_df.dropna()

# %%
newdf.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'Region', 'Notes'],
#       dtype='object')

# %%
newdf.shape
# Out:
# (430, 17)

# %%
newdf.isnull().sum()
# Out:
# ID        0
# Name      0
# Sex       0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# Region    0
# Notes     0
# dtype: int64

# %% [markdown]
# **Check the duplicate values:**

# %%
newdf.duplicated()
# Out:
# 3306      False
# 3680      False
# 5075      False
# 6517      False
# 6518      False
#           ...
# 270382    False
# 270388    False
# 270477    False
# 270827    False
# 270946    False
# Length: 430, dtype: bool

# %%
newdf.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #Check which row index is duplicated:

# %%
# duplicatedRows = df.index[df.duplicated()]
# print(f"Index positions of duplicate rows:{duplicatedRows}")

# %% [markdown]
# #Removing Duplicates:

# %%
# df.drop_duplicates(inplace = True)

# %%
# df.duplicated().sum()

# %%
newdf['Sex'].value_counts()
# Out:
# M    362
# F     68
# Name: Sex, dtype: int64

# %%
newdf['Age'].value_counts()
# Out:
# 22.0    58
# 26.0    45
# 23.0    43
# 24.0    40
# 27.0    36
# 25.0    36
# 28.0    30
# 21.0    29
# 29.0    25
# 19.0    24
# 20.0    18
# 30.0    17
# 33.0     5
# 31.0     5
# 18.0     4
# 32.0     3
# 36.0     3
# 34.0     2
# 16.0     2
# 14.0     1
# 49.0     1
# 17.0     1
# 52.0     1
# 38.0     1
# Name: Age, dtype: int64

# %%
newdf['Height'].value_counts()
# Out:
# 188.0    29
# 197.0    23
# 180.0    22
# 176.0    21
# 187.0    20
# 190.0    18
# 172.0    15
# 183.0    14
# 192.0    13
# 196.0    13
# 184.0    13
# 194.0    11
# 198.0    10
# 186.0    10
# 178.0    10
# 170.0    10
# 189.0    10
# 173.0    10
# 179.0     9
# 177.0     9
# 185.0     9
# 191.0     9
# 193.0     8
# 203.0     8
# 175.0     8
# 181.0     8
# 165.0     7
# 182.0     7
# 204.0     6
# 169.0     6
# 208.0     6
# 195.0     5
# 205.0     5
# 200.0     5
# 210.0     4
# 174.0     4
# 206.0     4
# 209.0     4
# 167.0     3
# 201.0     3
# 168.0     3
# 166.0     3
# 171.0     2
# 213.0     2
# 202.0     2
# 211.0     2
# 207.0     1
# 199.0     1
# 163.0     1
# 162.0     1
# 158.0     1
# 217.0     1
# 212.0     1
# Name: Height, dtype: int64

# %%
newdf['Weight'].value_counts()
# Out:
# 95.0     23
# 94.0     18
# 85.0     17
# 70.0     17
# 80.0     16
#          ..
# 106.0     1
# 47.0      1
# 114.0     1
# 53.0      1
# 66.0      1
# Name: Weight, Length: 61, dtype: int64

# %%
newdf['Team'].value_counts()
# Out:
# Yugoslavia                      321
# Serbia and Montenegro            61
# Trinidad and Tobago              29
# Individual Olympic Athletes       5
# West Indies Federation            5
# Australasia                       4
# Hong Kong-2                       2
# Hong Kong                         2
# United States Virgin Islands      1
# Name: Team, dtype: int64

# %%
newdf['NOC'].value_counts()
# Out:
# YUG    321
# SCG     61
# TTO     29
# IOA      5
# WIF      5
# ANZ      4
# HKG      4
# ISV      1
# Name: NOC, dtype: int64

# %%
newdf['Games'].value_counts()
# Out:
# 1984 Summer    87
# 1988 Summer    64
# 1980 Summer    56
# 1968 Summer    29
# 2000 Summer    27
# 1996 Summer    26
# 1960 Summer    22
# 1964 Summer    21
# 1976 Summer    20
# 1972 Summer    18
# 2004 Summer    16
# 2012 Summer    11
# 2008 Summer     6
# 1956 Summer     6
# 1988 Winter     6
# 2016 Summer     3
# 1908 Summer     3
# 1992 Summer     3
# 1952 Summer     3
# 1984 Winter     1
# 1948 Summer     1
# 1912 Summer     1
# Name: Games, dtype: int64

# %%
newdf['Year'].value_counts()
# Out:
# 1984    88
# 1988    70
# 1980    56
# 1968    29
# 2000    27
# 1996    26
# 1960    22
# 1964    21
# 1976    20
# 1972    18
# 2004    16
# 2012    11
# 2008     6
# 1956     6
# 2016     3
# 1952     3
# 1992     3
# 1908     3
# 1948     1
# 1912     1
# Name: Year, dtype: int64

# %%
newdf['Season'].value_counts()
# Out:
# Summer    423
# Winter      7
# Name: Season, dtype: int64

# %%
newdf['City'].value_counts()
# Out:
# Los Angeles       87
# Seoul             64
# Moskva            56
# Mexico City       29
# Sydney            27
# Atlanta           26
# Roma              22
# Tokyo             21
# Montreal          20
# Munich            18
# Athina            16
# London            15
# Calgary            6
# Beijing            6
# Melbourne          6
# Rio de Janeiro     3
# Helsinki           3
# Barcelona          3
# Sarajevo           1
# Stockholm          1
# Name: City, dtype: int64

# %%
newdf['Sport'].value_counts()
# Out:
# Basketball       95
# Water Polo       90
# Handball         72
# Athletics        36
# Football         35
# Volleyball       20
# Wrestling        16
# Shooting         12
# Boxing           11
# Rowing            9
# Canoeing          7
# Table Tennis      6
# Swimming          5
# Ski Jumping       5
# Gymnastics        3
# Alpine Skiing     2
# Sailing           2
# Judo              2
# Cycling           1
# Tennis            1
# Name: Sport, dtype: int64

# %%
newdf['Event'].value_counts()
# Out:
# Water Polo Men's Water Polo             90
# Basketball Men's Basketball             71
# Handball Men's Handball                 43
# Football Men's Football                 35
# Handball Women's Handball               29
#                                         ..
# Athletics Men's 3,500 metres Walk        1
# Judo Men's Heavyweight                   1
# Sailing Women's Windsurfer               1
# Cycling Women's Keirin                   1
# Tennis Men's Singles, Covered Courts     1
# Name: Event, Length: 68, dtype: int64

# %%
newdf['Medal'].value_counts()
# Out:
# Silver    154
# Gold      143
# Bronze    133
# Name: Medal, dtype: int64

# %%
newdf['Region'].value_counts()
# Out:
# Serbia                         382
# Trinidad                        34
# Individual Olympic Athletes      5
# Australia                        4
# China                            4
# Virgin Islands, US               1
# Name: Region, dtype: int64

# %%
newdf['Notes'].value_counts()
# Out:
# Yugoslavia                     321
# Serbia and Montenegro           61
# Trinidad and Tobago             29
# Individual Olympic Athletes      5
# West Indies Federation           5
# Australasia                      4
# Hong Kong                        4
# Virgin Islands                   1
# Name: Notes, dtype: int64

# %%
newdf.query('Team=="India"').head(5)
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal, Region, Notes]
# Index: []

# %%
# Top countries participation

top_countries= newdf.Team.value_counts().sort_values(ascending=False).head(10)
top_countries
# Out:
# Yugoslavia                      321
# Serbia and Montenegro            61
# Trinidad and Tobago              29
# Individual Olympic Athletes       5
# West Indies Federation            5
# Australasia                       4
# Hong Kong-2                       2
# Hong Kong                         2
# United States Virgin Islands      1
# Name: Team, dtype: int64

# %%
# Top countries plotting

plt.figure(figsize=(20,5))
#plt.xticks(rotation=20)
plt.title('Overall participation by countries')
sns.barplot(x=top_countries.index, y=top_countries, palette = 'Set2')
# Out:
# <Axes: title={'center': 'Overall participation by countries'}, ylabel='Team'>

# %%
plt.figure(figsize=(15,6))
plt.title("Age distribution of the athletes")
plt.xlabel('Age')
plt.ylabel('Number of participants')
plt.hist(newdf.Age, bins = np.arange(10,80,2), color='magenta', edgecolor='white');

# %%
# Winter Olympics Sports

winter_sports = newdf[athletes_df.Season == 'Winter'].Sport.unique()
winter_sports
# Out:
# <ipython-input-69-6ca47ba33b64>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   winter_sports = newdf[athletes_df.Season == 'Winter'].Sport.unique()
# array(['Ski Jumping', 'Alpine Skiing'], dtype=object)

# %%
# Summer Olympics Sports

summer_sports = newdf[athletes_df.Season == 'Summer'].Sport.unique()
summer_sports
# Out:
# <ipython-input-70-afa5c87734be>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   summer_sports = newdf[athletes_df.Season == 'Summer'].Sport.unique()
# array(['Shooting', 'Athletics', 'Handball', 'Water Polo', 'Football',
#        'Basketball', 'Volleyball', 'Swimming', 'Rowing', 'Gymnastics',
#        'Wrestling', 'Table Tennis', 'Sailing', 'Canoeing', 'Boxing',
#        'Judo', 'Cycling', 'Tennis'], dtype=object)

# %%
plt.figure(figsize=(14,8))
plt.title('Gender Distribution in Oylmpics')
plt.pie(gender_counts, labels=gender_counts.index,  autopct='%1.2f%%', startangle = 190);

# %%
# Total number of female athletes in each olympics

female_participants= newdf[(newdf.Sex=='F') & (newdf.Season=='Summer')][['Sex', 'Year']]
female_participants= female_participants.groupby('Year').count().reset_index()
female_participants.tail()
# Out:
#    Year  Sex
# 4  1992    2
# 5  1996    3
# 6  2000    1
# 7  2004    1
# 8  2012    1

# %%
womenOlympics = newdf[(newdf.Sex=='F') & (newdf.Season=='Summer')]

# %%
# Plotting of Women's Participation

sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
sns.countplot(x='Year', data = womenOlympics, palette="Spectral")
plt.title('Women Participation in the Olympics')
# Out:
# Text(0.5, 1.0, 'Women Participation in the Olympics')

# %% [markdown]
# **By the line graph so you can have the better understanding about how female athletes participation have increased over the years.**

# %%
part = womenOlympics.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(20, 10))
part.loc[:,'F'].plot()
plt.title('Plot of Female Athletes over the years')
# Out:
# Text(0.5, 1.0, 'Plot of Female Athletes over the years')

# %%
# Gold medal winnig athletes

goldMedals = newdf[(newdf.Medal=='Gold')]
goldMedals.head()
# Out:
#         ID                          Name Sex   Age  Height  Weight  \
# 3306  1858             Fehaid Al-Deehani   M  49.0   178.0    95.0
# 6518  3652  Svetlana Anastasovski-Obuina   F  23.0   176.0    65.0
# 7538  4202                  Dragan Andri   M  22.0   192.0    91.0
# 7539  4202                  Dragan Andri   M  26.0   192.0    91.0
# 7968  4410                Andrija Ankovi   M  23.0   177.0    79.0
#
#                              Team  NOC        Games  Year  Season  \
# 3306  Individual Olympic Athletes  IOA  2016 Summer  2016  Summer
# 6518                   Yugoslavia  YUG  1984 Summer  1984  Summer
# 7538                   Yugoslavia  YUG  1984 Summer  1984  Summer
# 7539                   Yugoslavia  YUG  1988 Summer  1988  Summer
# 7968                   Yugoslavia  YUG  1960 Summer  1960  Summer
#
#                 City       Sport                        Event Medal  \
# 3306  Rio de Janeiro    Shooting   Shooting Men's Double Trap  Gold
# ...

# %%
goldMedals = goldMedals[np.isfinite(goldMedals['Age'])]

# %%
# Gold won beyond the age 55

goldMedals['ID'][goldMedals['Age']>55].count()
# Out:
# 0

# %%
sporting_event = goldMedals['Sport'][goldMedals['Age']>55]
sporting_event.head()
# Out:
# Series([], Name: Sport, dtype: object)

# %%
# Plot for sporting event beyond age of 55

sns.set(style="darkgrid")
plt.figure(figsize=(12,6))
plt.tight_layout()
sns.countplot(sporting_event, palette="Set1")
plt.title('Gold Medals for Athletes over 55 years')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Number of Gold Medals from each country

goldMedals.Region.value_counts().reset_index(name='Medal')
# Out:
#                          index  Medal
# 0                       Serbia    134
# 1                     Trinidad      7
# 2  Individual Olympic Athletes      1
# 3                        China      1

# %%
# Plotting Gold medals per country

totalGoldmedals = goldMedals.Region.value_counts().reset_index(name='Medal').head(6)
g = sns.catplot(x="index", y="Medal", data = totalGoldmedals, height=5, kind="bar", palette="magma")
g.despine(left=True)
g.set_xlabels("Top 6 countries")
g.set_ylabels("Number of Medals")
plt.title('Gold Medals per Country')
# Out:
# Text(0.5, 1.0, 'Gold Medals per Country')

# %%
# Rio Oylmpics
max_year = athletes_df.Year.max()
print("Rio Olympics - 2016")
team_names = newdf[(newdf.Year== max_year) & (newdf.Medal=='Gold')].Team

team_names.value_counts().head(10)
# Out:
# Rio Olympics - 2016
# Individual Olympic Athletes    1
# Name: Team, dtype: int64

# %%
sns.barplot(x = team_names.value_counts().head(20), y= team_names.value_counts().head(20).index)

plt.ylabel(None);
plt.xlabel('Countrywise Medals for Rio Olympics 2016');

# %%
# df['Income'] = df[['ApplicantIncome' , 'CoapplicantIncome']].apply(lambda x: '{}+{}'.format(x[0], x[1]), axis=1) used for date or time
# df['Income'].head()

# %%
df['Income'] = df['ApplicantIncome']+df['CoapplicantIncome']
df['Income'].head()
# Out:
# 0    5849.0
# 1    6091.0
# 2    3000.0
# 3    4941.0
# 4    6000.0
# Name: Income, dtype: float64

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents Self_Employed  ApplicantIncome  \
# 0  LP001002   Male      No          0            No             5849
# 1  LP001003   Male     Yes          1            No             4583
# 2  LP001005   Male     Yes          0           Yes             3000
# 3  LP001006   Male     Yes          0            No             2583
# 4  LP001008   Male      No          0            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Income
# 0         Urban           Y  5849.0
# 1         Rural           N  6091.0
# ...

# %% [markdown]
# **Replacing the value of the rows if necessary:**

# %%
# # Replacing the values in the row
# replace_val = {'Male':0, 'Female':1}
# replace_valu = {'No': 0, 'Yes': 1}
# replace_value = {'No': 0, 'Yes': 1}
# df = df.replace({"Gender": replace_val})
# df = df.replace({"Married": replace_valu})
# df = df.replace({"Self_Employed": replace_value})

# df.head()

# %%
dataframe.shape
# Out:
# (480, 13)

# %%
dataframe.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History        Income
# count      480.000000    480.000000
# mean         0.854167   6945.324833
# std          0.353307   5969.948374
# min          0.000000   1442.000000
# 25%          1.000000   4148.000000
# 50%          1.000000   5422.500000
# 75%          1.000000   7672.500000
# ...

# %% [markdown]
# **Calculate the number of different values in each column**

# %%
unique_counts = dataframe.nunique()
unique_counts
# Out:
# Loan_ID              480
# Gender                 2
# Married                2
# Dependents             4
# Self_Employed          2
# ApplicantIncome      405
# CoapplicantIncome    232
# LoanAmount           186
# Loan_Amount_Term       9
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# Income               437
# dtype: int64

# %% [markdown]
# **Calculate the number of different values in each column using value_counts():**

# %%
dataframe.column = ['Gender', 'Married', 'Dependents',
       'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']
# Out:
# <ipython-input-23-2c938d1eb9e2>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dataframe.column = ['Gender', 'Married', 'Dependents',

# %%
for column in dataframe.column:
    value_counts = df[column].value_counts()
    print(f"Column '{column}' has {len(value_counts)} different values:\n{value_counts}\n")
# Out:
# Column 'Gender' has 2 different values:
# Male      489
# Female    112
# Name: Gender, dtype: int64
#
# Column 'Married' has 2 different values:
# Yes    398
# No     213
# Name: Married, dtype: int64
#
# Column 'Dependents' has 4 different values:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64
#
# Column 'Self_Employed' has 2 different values:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64
#
# Column 'ApplicantIncome' has 505 different values:
# 2500    9
# 4583    6
# 6000    6
# 2600    6
# 3333    5
#        ..
# 3244    1
# 4408    1
# 3917    1
# 3992    1
# 7583    1
# Name: ApplicantIncome, Length: 505, dtype: int64
#
# Column 'CoapplicantIncome' has 287 different values:
# 0.0       273
# 2500.0      5
# 2083.0      5
# 1666.0      5
# 2250.0      3
#          ...
# 2791.0      1
# 1010.0      1
# 1695.0      1
# 2598.0      1
# 240.0       1
# Name: CoapplicantIncome, Length: 287, dtype: int64
#
# ...

# %% [markdown]
# **Correlation:**

# %%
correlation_matrix= dataframe.corr()
correlation_matrix
# Out:
# <ipython-input-25-d5ca0003e774>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix= dataframe.corr()
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.112588    0.495310
# CoapplicantIncome        -0.112588           1.000000    0.190740
# LoanAmount                0.495310           0.190740    1.000000
# Loan_Amount_Term         -0.010838          -0.005775    0.050867
# Credit_History           -0.056152          -0.008692   -0.040773
# Income                    0.900097           0.331580    0.553914
#
#                    Loan_Amount_Term  Credit_History    Income
# ApplicantIncome           -0.010838       -0.056152  0.900097
# CoapplicantIncome         -0.005775       -0.008692  0.331580
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 8))
#sns.heatmap: This function from Seaborn library is used to plot the heatmap.
#annot=True: This option displays the correlation coefficients on the heatmap.
#cmap='coolwarm':
#This option sets the color map for the heatmap, where positive correlations are displayed in warmer colors (red) and negative correlations in cooler colors (blue).
#linewidths=0.5: This option sets the width of the lines separating each cell in the heatmap.
sns.heatmap(correlation_matrix, annot= True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **Correlation Graphs:**

# %%
# Select the two columns for which you want to show the correlation
x_column = 'LoanAmount'  # Replace 'column1' with the name of the first column
y_column = 'Loan_Status'  # Replace 'column2' with the name of the second column

# Plot the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=dataframe[x_column], y=dataframe[y_column])
plt.title(f"Correlation between {x_column} and {y_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.show()

# %%
df['Income'].max()
# Out:
# 81000.0

# %%
df['Income'].min()
# Out:
# 1442.0

# %%
# Select the two columns for which you want to show the correlation
x_column = 'LoanAmount'  # Replace 'column1' with the name of the first column
y_column = 'Income'  # Replace 'column2' with the name of the second column

# Plot the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=dataframe[x_column], y=dataframe[y_column])
plt.title(f"Correlation between {x_column} and {y_column}")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.show()
