# %% [markdown]
# **Creating a pandas series from list**

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.5.3

# %%
list = [4,6,7,"ali","8.9",12]
pd.Series(list)
# Out:
# 0      4
# 1      6
# 2      7
# 3    ali
# 4    8.9
# 5     12
# dtype: object

# %% [markdown]
# **Lables:**
# #Values are specified with their index number.

# %%
print(list[2])
# Out:
# 7

# %% [markdown]
# **Create Labels**
# #With the index argument, you can name your own labels.

# %%
list = [4,6,7,"ali","8.9",12]
res = pd.Series(list,index = ["u","v","w","x","y","z"])
res
# Out:
# u      4
# v      6
# w      7
# x    ali
# y    8.9
# z     12
# dtype: object

# %%
print(res["y"])
# Out:
# 8.9

# %% [markdown]
# **Create a simple Pandas Series from a dictionary:**

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ###To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series.

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ###Series is like a column, a DataFrame is the whole table
# create a dataframe from two series

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ###Locate Row

# %%
myvar.loc[1]     #return the pandas series
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
myvar.loc[[0,2]] # return the pandas dataframe
# Out:
#    calories  duration
# 0       420        50
# 2       390        45

# %% [markdown]
# **Named Indexed**
# ###With the index argument, you can name your own indexes.

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df.loc["day2"]
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataframe = pd.read_csv("/content/drive/My Drive/DataAnalysisWithPython/Libraries/data.csv")

# %%
dataframe.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
dataframe.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
dataframe.shape
# Out:
# (169, 4)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
dataframe.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
dataframe.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %% [markdown]
# **Check the specific column is present in our dataset or not:**

# %%
# Check if 'specific_column_name' is present in the DataFrame's columns
specific_column_name = 'Date'
if specific_column_name in df.columns:
    print(f"The column '{specific_column_name}' is present in the DataFrame.")
else:
    print(f"The column '{specific_column_name}' is not present in the DataFrame.")
# Out:
# The column 'Date' is not present in the DataFrame.

# %%
dataframe.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
dataframe.isnull().sum()  # isnull() is used to check is NaN value is present in our data set or not if NaN is present it return true.
#sum() is used to check how many null values we have.
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df = dataframe.dropna()  #dropna() is used to drop the  rows having NaN value of the columns.
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df['Pulse'].mean()
# Out:
# 107.67682926829268

# %%
df.shape   # 5 rows are drop
# Out:
# (164, 4)

# %% [markdown]
# **Check the specific index is present in the dataframe or not:**

# %%
specific_index_label = 26
if specific_index_label in df.index:
    print(f"The index label '{specific_index_label}' is present in the DataFrame.")
else:
    print(f"The index label '{specific_index_label}' is not present in the DataFrame.")
# Out:
# The index label '26' is present in the DataFrame.

# %% [markdown]
# #Accessing the row by using the specific index:

# %%
df.loc[22]
# Out:
# Duration     60.0
# Pulse       130.0
# Maxpulse    101.0
# Calories    300.0
# Name: 22, dtype: float64

# %%
df.iloc[26]
# Out:
# Duration     60.0
# Pulse       100.0
# Maxpulse    132.0
# Calories    280.0
# Name: 28, dtype: float64

# %% [markdown]
# #Cleaning the wrong data:

# %%
for x in df.index:
  if df.loc[x,"Duration"] > 60:
    df.loc[x,"Duration"] = 55

# %%
df["Duration"]
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
#        ..
# 164    60
# 165    60
# 166    60
# 167    55
# 168    55
# Name: Duration, Length: 164, dtype: int64

# %%
#second way to cleaning the data when our data is large
# for x in df.index:
#   if df.loc[x, "Duration"] > 120:
#     df.drop(x, inplace = True)

# %% [markdown]
# #Checking Duplicate:

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 164, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 7

# %% [markdown]
# #Check which row index is duplicated:

# %%
duplicatedRows = df.index[df.duplicated()]
print(f"Index positions of duplicate rows:{duplicatedRows}")
# Out:
# Index positions of duplicate rows:Int64Index([36, 37, 38, 40, 71, 113, 155], dtype='int64')

# %% [markdown]
# #Removing Duplicates:

# %%
print(df.drop_duplicates(inplace = True))
# Out:
# None
# <ipython-input-37-c2b560b00c68>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   print(df.drop_duplicates(inplace = True))

# %% [markdown]
# The (inplace = True) will make sure that the method does NOT return a new DataFrame, but it will remove all duplicates from the original DataFrame.It modify the original dataset without creating the new dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(df.to_string())       #to_string() is used to return the entire dataframe
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
pd.options.display.max_rows  #default maximum value is 60 or 100  if we set 10 then it on;y show the first 10 rows
# Out:
# 60

# %%
pd.options.display.max_rows = None # it will show all the rows

# %%
df.max()
# Out:
# Duration      60.0
# Pulse        159.0
# Maxpulse     184.0
# Calories    1860.4
# dtype: float64

# %%
df.min()
# Out:
# Duration     15.0
# Pulse        80.0
# Maxpulse    100.0
# Calories     50.3
# dtype: float64

# %% [markdown]
# #Data Correlation:

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.259927 -0.151747  0.349971
# Pulse    -0.259927  1.000000  0.784994  0.015301
# Maxpulse -0.151747  0.784994  1.000000  0.195309
# Calories  0.349971  0.015301  0.195309  1.000000

# %% [markdown]
# #Plotting:

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
df.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-bb76a30db107> in <cell line: 2>()
#       1 df.plot()
# ----> 2 df.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'show'

# %%
#df['Duration'].value_counts()

# %% [markdown]
# #Scatter plot:

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
plt.show()

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Maxpulse')
plt.show()

# %%
ax = df['Duration'].plot(kind='density', figsize=(14,6)) # kde
ax.axvline(df['Duration'].mean(), color='red',linestyle = '--',linewidth=2)
ax.axvline(df['Duration'].median(), color='green')

# %% [markdown]
# **Read JSON:**

# %%
import json

# %%
df = pd.read_json('/content/drive/My Drive/DataAnalysisWithPython/Libraries/data.json')

# %%
print(df.to_string())  # return the entire dataframe
# Out:
#                                                        Duration
# 0        {'0': 60, '1': 60, '2': 60, '3': 45, '4': 45, '5': 60}
# 1  {'0': 110, '1': 117, '2': 103, '3': 109, '4': 117, '5': 102}
# 2  {'0': 130, '1': 145, '2': 135, '3': 175, '4': 148, '5': 127}
# 3  {'0': 409, '1': 479, '2': 340, '3': 282, '4': 406, '5': 300}
